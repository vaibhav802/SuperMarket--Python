# %% [markdown]
# ### Store

# %%
stationary={
            'pen':{'brand':{'link':{'price':[5,10],'stock':[200,100]},
                            'fine':{'price':[5,10],'stock':[250,150]}
                           }
                  },
            'register':{'brand':{'classmate':{'price':[50,80],'stock':[100,50]},
                            'icon':{'price':[50,60],'stock':[200,80]}
                           }
                      },
            'books':{'class VI':{'price':500,'stock':20},
                     'class VII':{'price':600,'stock':20},
                     'class VIII':{'price':700,'stock':20},
                     'class IX':{'price':800,'stock':20},
                     'class X':{'price':900,'stock':20},
                    }
}
print(type(stationary))

electronics={
            'mobile':{'brand':{'one plus':{'model':['7 pro','8 pro','7'],'price':[40000,46000,35000],'stock':[20,20,10]},
                              'iphone':{'model':['6','10','11'],'price':[20000,56000,100000],'stock':[20,20,10]},
                              'MI':{'model':['10 pro','8 pro','8A','7 pro','6A'],'price':[40000,15000,9000,10000,8000],'stock':[20,50,50,30,100]}
                             }
                  },
            'laptop':{'brand':{'hp':{'model':['HP Pavilion Gaming 15','HP Omen 15','HP Spectre x360 (2019)'],'price':[55000,95000,150000],'stock':[5,5,5]},
                              'samsung':{'model':['Samsung ChromeBook XE50','Samsung ChromeBook 3 XE501C13-K01US','Samsung Spin 7 NP730QAA'],'price':[25000,46000,90000],'stock':[20,20,10]},
                              'dell':{'model':['Dell Inspiron Core','Dell Inspiron Touchscreen 15 5548 Notebook','Dell Vostro 3458'],'price':[25000,75000,29000],'stock':[15,10,20]}
                             }
                  }
}



cosmatic={
            'bodylotion':{'brand':{'joy':{'price':[50,100],'stock':[100,50]},
                                   'vaseline':{'price':[120,200],'stock':[120,100]}
                           }
                  },
            'soap':{'brand':{'lifeboy':{'price':[10,20],'stock':[100,50]},
                            'dettol':{'price':[20,40],'stock':[200,80]},
                            'godrej no.1 ':{'price':[15,25],'stock':[200,80]},
                           }
                },
            'cream':{'brand':{'boroplus':{'price':[20,40],'stock':[100,50]},
                            'fair Handsome':{'price':[20,40],'stock':[200,80]},
                            'meglow':{'price':[50,100],'stock':[200,80]},
                           }
                   },
            'perfume':{'brand':{'denver':{'price':[100,200],'stock':[100,50]},
                            'park avenue':{'price':[120,180],'stock':[200,80]},
                            'fogg':{'price':[150,195],'stock':[200,80]},
                           }
                   }
}



chocolate={
            'munch':{'price':[5,10,20,40,60],'stock':[100,90,80,70,60]},
            'kit-kat':{'price':[5,10,20,40,60],'stock':[100,90,80,70,60]},
            'five star':{'price':[5,10,20,40],'stock':[100,80,70,60]},
            'perk':{'price':[5,10,20,40],'stock':[100,90,80,70]}
}
# Out:
# <class 'dict'>

# %%
# import os
# os.mkdir('Supermarket/')
# f['stationary']=stationary 
# f['electronics']=electronics
# f['cosmatic']= cosmatic
# f['chocolate']=chocolate

# %%
import os 
import shelve
import time
f = shelve.open('Supermarket/storage.db',writeback=True)
os.system('cls')
l = ["Item\tProduct\tBrand\tQt\tPrice/qt\tTotal"]
def Main():
    print(' '*50,'Welcome to the Supermarket')
    print('Itmes Available in the store')
    s = """1. Stationary\n2. Electronics\n3. Cosmatics\n4. Chocolate\n.Choose any key above 4, You can Exit from the store.\n"""
    print(s)
    try:
        choice = int(input('Enter the choice you want:'))
    except Exception as e:
        print(' '*50,'\n Enter a VALID CHOICE!')
        return Main()
    if choice == 1:
        stationary()
    elif choice == 2:
        electronics()
    elif choice==3:
        cosmatic()
    elif choice == 4:
        chocolate()
    else:
        exit()
def stationary():
    f = shelve.open('Supermarket/storage.db',writeback=True)
    data = f['stationary']
    print('Available items in Stationary')
    c = 1
    for i in data:
        print(c,'.',i.capitalize(),sep='')
        c+=1
    print(f'. Choose any key above {c-1} to back to Main menu',sep='')
    try:
        choice = int(input('\n\nEnter the choice you want:'))
    except Exception as e:
        print(' '*50,'\n Enter a VALID CHOICE!')
        return stationary()
    if choice ==1:
        print('\n\n Available brands in store:')
        c=1
        for i in data['pen']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand you want:'))
        except Exception as e:
            print(' '*50,'\n Enter a VALID CHOICE!')
            return stationary() 
        if choice ==1:
            b = data['pen']['brand']['link']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of Pen you want:'))
            except Exception as e:
                print(' '*50,'\n Enter a VALID CHOICE!')
                return stationary()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the number of Pen you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter a VALID CHOICE!')
                    return stationary()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Stationary\tPen\tLink\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    stationary()
                else:
                    print('stock not Available')
                    stationary()
            else:
                print('Price not Available')
                stationary()
        elif choice==2:
            b = data['pen']['brand']['fine']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of Pen you want:'))
            except Exception as e:
                print(' '*50,'\n Enter a VALID CHOICE!')
                return stationary()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the number of Pen you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter a VALID CHOICE!')
                    return stationary()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Stationary\tPen\tFine\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    stationary()   
                else:
                    print('stock not Available')
                    stationary()
            else:
                print('Price not Available')
                stationary()
        else:
            print('Invalid choice')
            stationary()
    elif choice==2:
        print('\n\n Available brands in store:')   
        c=1
        for i in data['register']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
            print(' '*50,'\n Enter a VALID CHOICE!')
            return stationary()
        if choice ==1:
            b = data['register']['brand']['classmate']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of Register you want:'))
            except Exception as e:
                print(' '*50,'\n Enter a VALID CHOICE!')
                return stationary()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the number of Register you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter a VALID CHOICE!')
                    return stationary()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Stationary\tRegister\tClassmate\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    stationary()
                else:
                    print('stock not Available')
                    stationary()
            else:
                print('Price not Available')
                stationary()
        elif choice==2:
            b = data['register']['brand']['icon']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of Register you want:'))
            except Exception as e:
                print(' '*50,'\n Enter a VALID CHOICE!')
                return stationary()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the number of Register you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an integer number')
                    return stationary()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Stationary\tRegister\tIcon\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    stationary()  
                else:
                    print('stock not Available')
                    stationary()
            else:
                print('Price not Available')
                stationary()
        else:
            print('Invalid choice')
            stationary()   
    elif choice==3:
        print('\n\n Available Books in store:')
        c=1
        for i in data['books']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        print(f'.Enter any key above {c-1} to back')
        try:
            choice = int(input('\n\nEnter the number of class:'))
        except Exception as e:
            print(' '*50,'\n Enter a VALID CHOICE!')
            return stationary()
        if choice ==1:
            b = data['books']['class VI']
            print('Price',b['price'])
            try:
                qt = int(input('Enter the Quatity:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!')
                return stationary()
            if b['stock']>=qt:
                b['stock']-=qt
                f.close()
                l.append(f"Stationary\tBooks\tClass VI\t{qt}\tb['price']\t{qt*b['price']}")
                print('Order completed\n')
                stationary()
            else:
                print('Stock not Available')
                stationary()
        elif choice ==2:
            b = data['books']['class VII']
            print('Price',b['price'])
            try:
                qt = int(input('Enter the Quatity:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!')
                return stationary()
            if b['stock']>=qt:
                b['stock']-=qt
                f.close()
                l.append(f"Stationary\tBooks\tClass VII\t{qt}\tb['price']\t{qt*b['price']}")
                print('Order completed\n')
                stationary()
            else:
                print('Stock not Available')
                stationary()
        elif choice ==3:
            b = data['books']['class VIII']
            print('Price',b['price'])
            try:
                qt = int(input('Enter the Quatity:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!')
                return stationary()
            if b['stock']>=qt:
                b['stock']-=qt
                f.close()
                l.append(f"Stationary\tBooks\tClass VIII\t{qt}\tb['price']\t{qt*b['price']}")
                print('Order completed\n')
                stationary()
            else:
                print('Stock not Available')
                stationary()
        elif choice ==4:
            b = data['books']['class IX']
            print('Price',b['price'])
            try:
                qt = int(input('Enter the Quatity:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!')
                return stationary()
            if b['stock']>=qt:
                b['stock']-=qt
                f.close()
                l.append(f"Stationary\tBooks\tClass IX\t{qt}\tb['price']\t{qt*b['price']}")
                print('Order completed\n')
                stationary()
            else:
                print('Stock not Available')
                stationary()
        elif choice ==5:
            b = data['books']['class X']
            print('Price',b['price'])
            try:
                qt = int(input('Enter the Quatity:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!')
                return stationary()
            if b['stock']>=qt:
                b['stock']-=qt
                f.close()
                l.append(f"Stationary\tBooks\tClass X\t{qt}\tb['price']\t{qt*b['price']}")
                print('Order completed\n')
                stationary()
            else:
                print('Stock not Available')
                stationary()
        else:
            print('Invalid choice')
            stationary()
    else:
        Main()
def electronics():
    f = shelve.open('Supermarket/storage.db',writeback=True)
    data = f['electronics']
    print('Available items in Electronics')
    c = 1
    for i in data:
        print(c,'.',i.capitalize(),sep='')
        c+=1
    print(f'. Choose any key above {c-1} to back to Main menu',sep='')
    try:
        choice = int(input('\n\nEnter the choice:'))
    except Exception as e:
        print(' '*50,'\n Enter an VALID CHOICE!\n')
        return electronics()
    if choice ==1:  
        print('\n\n Available brands in store:') 
        c=1
        for i in data['mobile']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return electronics()
        if choice ==1:
            b = data['mobile']['brand']['one plus']
            print('Availble models',b['model'],'\n',b['price'])
            try:
                model= input('\nEnter the number of model you want:')
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return electronics()
            if model in b['model']:
                ind = b['model'].index(model)
                try:
                    qt = int(input('\nEnter the quantity of model you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return electronics()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Electronic\tMobile\tOneplus-{model}\t{qt}\tb['price']\t{qt*b['price']}")
                    print('\nYour order is completed\n')
                    electronics()
                else:
                    print('stock not Available')
                    electronics()
            else:
                print('Model not Available')
                electronics()
        elif choice==2:
            f = shelve.open('Supermarket/storage.db',writeback=True)
            data = f['electronics']
            b = data['mobile']['brand']['iphone']
            print('Availble models',b['model'],'\n',b['price'])
            try:
                model = input('\nEnter the number of model you want:')
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return electronics()
            if model in b['model']:
                ind = b['model'].index(model)
                try:
                    qt = int(input('\nEnter the quantity of model you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return electronics()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Electronic\tMobile\tiphone-{model}\t{qt}\tb['price']\t{qt*b['price']}")
                    print('\nYour order is completed\n')
                    electronics() 
                else:
                    print('stock not Available')
                    electronics()
            else:
                print('Price not Available')
                electronics()
        elif choice==3:
            f = shelve.open('Supermarket/storage.db',writeback=True)
            data = f['electronics']
            b = data['mobile']['brand']['MI']
            print('Availble models',b['model'],'\n',b['price'])
            try:
                model = input('\nEnter the number of model you want:')
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return electronics()
            if model in b['model']:
                ind = b['model'].index(model)
                try:
                    qt = int(input('\nEnter the quantity of model you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return electronics()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Electronic\tMobile\tMI-{model}\t{qt}\tb['price']\t{qt*b['price']}")
                    print('\nYour order is completed\n')
                    electronics()  
                else:
                    print('stock not Available')
                    electronics()
            else:
                print('Price not Available')
                electronics()
        else:
            print('Invalid choice')
            electronics()
    elif choice==2:
        print('\n\n Available brands in store:')
        c=1
        for i in data['laptop']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return electronics()
        if choice ==1:
            b = data['laptop']['brand']['hp']
            print('Availble models with thier prices ',b['model'],'\n',b['price'])
            try:
                model = input('\nEnter the number of model you want:')
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return electronics()
            if model in b['model']:
                ind = b['model'].index(model)
                try:
                    qt = int(input('\nEnter the quantity you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return electronics()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Electronic\tLaptop\thp-{model}\t{qt}\tb['price']\t{qt*b['price']}")
                    print('\nYour order is completed\n')
                    electronics()
                else:
                    print('stock not Available')
                    electronics()
            else:
                print('Price not Available')
                electronics()
        elif choice==2:
            b = data['laptop']['brand']['samsung']
            print('Availble model and prices',b['model'],'\n',b['price'])
            try:
                model = input('\nEnter the number of model you want:')
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return electronics()
            if model in b['model']:
                ind = b['model'].index(model)
                try:
                    qt = int(input('\nEnter the quantity of model you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return electronics()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Electronic\tLaptop\tSamsung-{model}\t{qt}\tb['price']\t{qt*b['price']}")
                    print('\nYour order is completed\n')
                    electronics()  
                else:
                    print('stock not Available')
                    electronics()
            else:
                print('Price not Available')
                electronics()
        elif choice==3:
            b = data['laptop']['brand']['dell']
            print('Availble model and prices',b['model'],'\n',b['price'])
            try:
                model = input('\nEnter the number of model you want:')
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return electronics()
            if model in b['model']:
                ind = b['model'].index(model)
                try:
                    qt = int(input('\nEnter the quantity of model you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return electronics()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Electronic\tLaptop\tDell-{model}\t{qt}\tb['price']\t{qt*b['price']}")
                    print('\nYour order is completed\n')
                    electronics()
                else:
                    print('stock not Available')
                    electronics()
            else:
                print('Price not Available')
                electronics()
        else:
            print('Invalid choice')
            electronics()
    else:
        Main()
def cosmatic():
    f = shelve.open('Supermarket/storage.db',writeback=True)
    data = f['cosmatic']
    print('Available items in cosmatic')
    c = 1
    for i in data:
        print(c,'.',i.capitalize(),sep='')
        c+=1
    print(f'. Choose any key above {c-1} to back to Main menu',sep='')
    try:
        choice = int(input('\n\nEnter the choice:'))
    except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return cosmatic()
    if choice ==1:
        print('\n\n Available brands in store:')
        c=1
        for i in data['bodylotion']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return cosmatic()
        if choice ==1:
            b = data['bodylotion']['brand']['joy']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of lotion you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the quantity of lotion you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tBodylotion\tJoy\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==2:
            b = data['bodylotion']['brand']['vaseline']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of lotion you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the quantity of lotion you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tBodylotion\tVaseline\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()       
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        else:
            print('Invalid choice')
            cosmatic()
    elif choice==2:
        print('\n\n Available brands in store:') 
        c=1
        for i in data['soap']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return cosmatic()
        if choice ==1:
            b = data['soap']['brand']['lifeboy']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of soap you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of soap you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tSoap\tLifeboy\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==2:
            b = data['soap']['brand']['dettol']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of soap you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of soap you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tSoap\tDettol\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==3:
            b = data['soap']['brand']['godrej no.1']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of soap you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of soap you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tSoap\tGodrej no.1\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        else:
            print('Invalid choice')
            cosmatic()
    elif choice==3:
        print('\n\n Available brands in store:')
        c=1
        for i in data['cream']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return cosmatic()
        if choice ==1:
            b = data['cream']['brand']['boroplus']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of cream you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of cream you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tCream\tBoroplus\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==2:
            b = data['cream']['brand']['fair Handsome']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of cream you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of cream you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tCream\tFair Handsome\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==3:
            b = data['cream']['brand']['meglow']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of cream you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of cream you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tCream\tMeglow\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        else:
            print('Invalid choice')
            cosmatic()
    elif choice==4:
        print('\n\n Available brands in store:')  
        c=1
        for i in data['perfume']['brand']:
            print(c,'.',i.capitalize(),sep='')
            c+=1
        try:
            choice = int(input('\n\nEnter the brand number:'))
        except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
        if choice ==1:
            b = data['perfume']['brand']['denver']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of perfume you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of perfume you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tPerfume\tDenver\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==2:
            b = data['perfume']['brand']['park avenue']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of perfume you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of perfume you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tPerfume\tPark avenue\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        elif choice==3:
            b = data['perfume']['brand']['fogg']
            print('Availble prices',b['price'])
            try:
                price = int(input('\nEnter the price of perfume you want:'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return cosmatic()
            if price in b['price']:
                ind = b['price'].index(price)
                try:
                    qt = int(input('\nEnter the Quantity of perfume you Want:'))
                except Exception as e:
                    print(' '*50,'\n Enter an VALID CHOICE!\n')
                    return cosmatic()
                if b['stock'][ind]>=qt:
                    b['stock'][ind]-=qt
                    f.close()
                    l.append(f"Cosmatic\tPerfume\tFogg\t{qt}\t{price}\t{qt*price}")
                    print('\nYour order is completed\n')
                    cosmatic()
                else:
                    print('stock not Available')
                    cosmatic()
            else:
                print('Price not Available')
                cosmatic()
        else:
            print('Invalid choice')
            cosmatic()
    else:
        Main()         
def chocolate():
    f = shelve.open('Supermarket/storage.db',writeback=True)
    data = f['chocolate']
    print('Available chocolate')
    c = 1
    for i in data:
        print(c,'.',i.capitalize(),sep='')
        c+=1
    print(f'. Choose any key above {c-1} to back to Main menu',sep='')
    try:
        choice = int(input('\n\nEnter the choice:'))
    except Exception as e:
        print(' '*50,'\n Enter an VALID CHOICE!\n')
        return chocolate()
    if choice ==1:
        data = f['chocolate']['dairymilk']
        print('Chocolate Price',data['price'])
        try:
            price = int(input("Enter the price of chocolate you want"))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return chocolate()
        if price in data['price']:
            ind = data['price'].index(price)
            try:
                qt = int(input('Enter the Quantity of chocolate'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return chocolate()
            if data['stock'][ind]>=qt:
                data['stock'][ind]-=qt
                f.close()
                l.append(f"Chocolate\tDairymilk\tNA\t{qt}\t{price}\t{qt*price}")
                print('\nYour order is completed\n')
                chocolate()
            else:
                print('stock not Available')
                chocolate()
        else:
            print('Price not Available')
            chocolate() 
    elif choice ==2:
        data = f['chocolate']['munch']
        print('Chocolate Price',data['price'])
        try:
            price = int(input("Enter the price of chocolate you want"))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return chocolate()
        if price in data['price']:
            ind = data['price'].index(price)
            try:
                qt = int(input('Enter the Quantity of chocolate'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return chocolate()
            if data['stock'][ind]>=qt:
                data['stock'][ind]-=qt
                f.close
                l.append(f"Chocolate\tMunch\tNA\t{qt}\t{price}\t{qt*price}")
                print('\nYour order is completed\n')
                chocolate()
            else:
                print('stock not Available')
                chocolate()
        else:
            print('Price not Available')
            chocolate()
    elif choice ==3:
        data = f['chocolate']['kit-kat']
        print('Chocolate Price',data['price'])
        try:
            price = int(input("Enter the price of chocolate you want"))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return chocolate()
        if price in data['price']:
            ind = data['price'].index(price)
            try:
                qt = int(input('Enter the Quantity of chocolate'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return chocolate()
            if data['stock'][ind]>=qt:
                data['stock'][ind]-=qt
                f.close()
                l.append(f"Chocolate\tKit-kat\tNA\t{qt}\t{price}\t{qt*price}")
                print('\nYour order is completed\n')
                chocolate()
            else:
                print('stock not Available')
                chocolate()
        else:
            print('Price not Available')
            chocolate()
    elif choice ==4:
        data = f['chocolate']['five star']
        print('Chocolate Price',data['price'])
        try:
            price = int(input("Enter the price of chocolate you want"))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return chocolate()
        if price in data['price']:
            ind = data['price'].index(price)
            try:
                qt = int(input('Enter the Quantity of chocolate'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return chocolate()
            if data['stock'][ind]>=qt:
                data['stock'][ind]-=qt
                f.close()
                l.append(f"Chocolate\tFive star\tNA\t{qt}\t{price}\t{qt*price}")
                print('\nYour order is completed\n')
                chocolate()
            else:
                print('stock not Available')
                chocolate()
        else:
            print('Price not Available')
            chocolate()
    elif choice ==5:
        data = f['chocolate']['perk']
        print('Chocolate Price',data['price'])
        try:
            price = int(input("Enter the price of chocolate you want"))
        except Exception as e:
            print(' '*50,'\n Enter an VALID CHOICE!\n')
            return chocolate()
        if price in data['price']:
            ind = data['price'].index(price)
            try:
                qt = int(input('Enter the Quantity of chocolate'))
            except Exception as e:
                print(' '*50,'\n Enter an VALID CHOICE!\n')
                return chocolate()
            if data['stock'][ind]>=qt:
                data['stock'][ind]-=qt
                f.close()
                l.append(f"Chocolate\tPerk\tNA\t{qt}\t{price}\t{qt*price}")
                print('\nYour order is completed\n')
                chocolate()
            else:
                print('stock not Available')
                chocolate()
        else:
            print('Price not Available')
            chocolate()
    else:
        print('Invalid choice')
        Main()

        
def exit():
    global l

    for i in l:
    
        for j in i.split('\t'):

            print(f"{j :>10}",end='\t')

        print()
        print('_'*100)

    price = 0
    for i in l[1:]:

        price = price + int(i.split('\t')[-1])
    print()   
    print('Grand Total:-'.ljust(85,' '),price)
    l = ["item\tProduct\tBrand\tQt\tPrice/qt\tTotal"]
    print('\n...............................Thank you for visiting...........................\n')
Main()
# Out:
#                                                    Welcome to the Supermarket
# Itmes Available in the store
# 1. Stationary
# 2. Electronics
# 3. Cosmatics
# 4. Chocolate
# .Choose any key above 4, You can Exit from the store.
#
# Enter the choice you want:5
#       Item	   Product	     Brand	        Qt	  Price/qt	     Total
# ____________________________________________________________________________________________________
#
# Grand Total:-                                                                         0
#
# ...............................Thank you for visiting...........................
